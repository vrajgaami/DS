# %%
l1 = [1, 2, 3, 4]
l2 = [3, 4, 5, 6]
new_list = l1 + l2
print(new_list)
# Out:
# [1, 2, 3, 4, 3, 4, 5, 6]

# %%
#Find maximum element combining two list l1 and l2
l1 = [1, 2, 3, 4]
l2 = [3, 4, 5, 6]
new_list = l1 + l2
print(max(new_list))
# Out:
# 6

# %%
#find common elemnts from list l1 and l2
l1 = {1, 2, 3, 4}
l2 = {3, 4, 5, 6}
print(l1 & l2)
# Out:
# {3, 4}

# %%
d1 = {'a': 1, 'b': 2, 'c': 3, 'd': 4}
d2 = {'a': 7, 'f': 2, 'g': 55, 'h': "101"}
keys1 = set(d1.keys())
keys2 = set(d2.keys())
#find common key from d1 and d2
print("Common Keys:", common_keys)
#find common value from d1 and d2
print("Common Values:", common_values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-0bb53279ef72> in <cell line: 6>()
#       4 keys2 = set(d2.keys())
#       5 #find common key from d1 and d2
# ----> 6 print("Common Keys:", common_keys)
#       7 #find common value from d1 and d2
#       8 print("Common Values:", common_values)
#
# NameError: name 'common_keys' is not defined

# %%
#replace the values of d1 to their negatie value
for key, value in d1.items():
  d1[key]=-value
  print(d1)
# Out:
# {'a': -1, 'b': 2, 'c': 3, 'd': 4}
# {'a': -1, 'b': -2, 'c': 3, 'd': 4}
# {'a': -1, 'b': -2, 'c': -3, 'd': 4}
# {'a': -1, 'b': -2, 'c': -3, 'd': -4}

# %%
#replace key to value and value to key in d2
d2 = {value: key for key, value in d2.items()}
print(d2)
# Out:
# {7: 'a', 2: 'f', 55: 'g', '101': 'h'}
